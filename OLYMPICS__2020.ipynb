# %% [markdown]
# <a href="https://colab.research.google.com/github/ynlare/Merge-Sort-and-Filter-Data-in-Python-Pandas/blob/main/OLYMPICS__2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# >      **Olympic Games Analytics Project Using Python and Pandas**

# %% [markdown]
# # Olympics medal count 2021: Final table of gold, silver, bronze medals in overall standings

# %%
from IPython import display
display.Image("/content/drive/MyDrive/Data_Engineering/Tokyo Olympics 2020(2021)/vector-set-pictograms-summer-olympic-games-saint-petersburg-russia-june-sport-icons-logos-tokyo-silhouette-sign-collection-222467539.jpeg", width = 1000, height = 400)

# %%
#pip install pywedge
# !pip install pywedge

# %%
import pandas as pd
import pywedge as pw
import seaborn as sns

# %% [markdown]
# # Which country has won the most Olympic medals?

# %%
# Import library python

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
import openpyxl

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import Excel files

dfom = pd.read_excel('/content/drive/MyDrive/Data_Engineering/Tokyo Olympics 2020(2021)/Olympic Medal Count 2020.xlsx',
                    sheet_name='Olympic Medal Count 2020')

dfom.set_index('Team/NOC', inplace=True)

# %%
dfom
# Out:
#                             Rank  Gold Medal  Silver Medal  Bronze Medal  \
# Team/NOC
# United States of America     1.0        39.0          41.0          33.0
# People's Republic of China   2.0        38.0          32.0          18.0
# Japan                        3.0        27.0          14.0          17.0
# Great Britain                4.0        22.0          21.0          22.0
# ROC                          5.0        20.0          28.0          23.0
# ...                          ...         ...           ...           ...
# Ghana                       86.0         0.0           0.0           1.0
# Grenada                     86.0         0.0           0.0           1.0
# Kuwait                      86.0         0.0           0.0           1.0
# Republic of Moldova         86.0         0.0           0.0           1.0
# Syrian Arab Republic        86.0         0.0           0.0           1.0
#
#                             Total  Rank by Total
# Team/NOC
# ...

# %%
## convertion: Columns to string
## https://www.codeforests.com/2020/08/16/pandas-format-column-headers/
dfom.columns =list(map( str,dfom.columns)) # or

dfom.columns = dfom.columns.astype("str") # or

#Index.str method
dfom.columns = dfom.columns.str.upper() # or

#Index.map method
dfom.columns = dfom.columns.map(str.upper)# or

#Python built-in map method
dfom.columns = map(str.upper, dfom.columns)

# %%
df_check = dfom.head()
df_check
# Out:
#                             RANK  GOLD MEDAL  SILVER MEDAL  BRONZE MEDAL  \
# Team/NOC
# United States of America     1.0        39.0          41.0          33.0
# People's Republic of China   2.0        38.0          32.0          18.0
# Japan                        3.0        27.0          14.0          17.0
# Great Britain                4.0        22.0          21.0          22.0
# ROC                          5.0        20.0          28.0          23.0
#
#                             TOTAL  RANK BY TOTAL
# Team/NOC
# United States of America    113.0            1.0
# People's Republic of China   88.0            2.0
# Japan                        58.0            5.0
# Great Britain                65.0            4.0
# ROC                          71.0            3.0

# %%
#  Information about  DataFrame including the index dtype and column dtypes, non-null values and memory usage
df_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, United States of America to ROC
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RANK           5 non-null      float64
#  1   GOLD MEDAL     5 non-null      float64
#  2   SILVER MEDAL   5 non-null      float64
#  3   BRONZE MEDAL   5 non-null      float64
#  4   TOTAL          5 non-null      float64
#  5   RANK BY TOTAL  5 non-null      float64
# dtypes: float64(6)
# memory usage: 280.0+ bytes

# %% [markdown]
# # Descriptive Statistics

# %%
dfom[["GOLD MEDAL","SILVER MEDAL","BRONZE MEDAL","TOTAL"]].describe()
# Out:
#        GOLD MEDAL  SILVER MEDAL  BRONZE MEDAL       TOTAL
# count   93.000000     93.000000     93.000000   93.000000
# mean     3.655914      3.634409      4.322581   11.612903
# std      7.022471      6.626339      6.210372   19.091332
# min      0.000000      0.000000      0.000000    1.000000
# 25%      0.000000      0.000000      1.000000    2.000000
# 50%      1.000000      1.000000      2.000000    4.000000
# 75%      3.000000      4.000000      5.000000   11.000000
# max     39.000000     41.000000     33.000000  113.000000

# %% [markdown]
# # Select rows in a DataFrame based on column values.

# %%
# 
  
dfom[(dfom['GOLD MEDAL'] > 3.655914) & (dfom['SILVER MEDAL'] > 3.634409) & (dfom['BRONZE MEDAL'] > 4.322581)]
# Out:
#                             RANK  GOLD MEDAL  SILVER MEDAL  BRONZE MEDAL  \
# Team/NOC
# United States of America     1.0        39.0          41.0          33.0
# People's Republic of China   2.0        38.0          32.0          18.0
# Japan                        3.0        27.0          14.0          17.0
# Great Britain                4.0        22.0          21.0          22.0
# ROC                          5.0        20.0          28.0          23.0
# Australia                    6.0        17.0           7.0          22.0
# Netherlands                  7.0        10.0          12.0          14.0
# France                       8.0        10.0          12.0          11.0
# Germany                      9.0        10.0          11.0          16.0
# Italy                       10.0        10.0          10.0          20.0
# Canada                      11.0         7.0           6.0          11.0
# Brazil                      12.0         7.0           6.0           8.0
# ...

# %% [markdown]
# # Select the rows by conditions if the values of the rows correspond to the average value of the different medals

# %%
above_mean = dfom[(dfom['GOLD MEDAL'] > 3.655914) & (dfom['SILVER MEDAL'] > 3.634409) & (dfom['BRONZE MEDAL'] > 4.322581)]
above_mean
# Out:
#                             RANK  GOLD MEDAL  SILVER MEDAL  BRONZE MEDAL  \
# Team/NOC
# United States of America     1.0        39.0          41.0          33.0
# People's Republic of China   2.0        38.0          32.0          18.0
# Japan                        3.0        27.0          14.0          17.0
# Great Britain                4.0        22.0          21.0          22.0
# ROC                          5.0        20.0          28.0          23.0
# Australia                    6.0        17.0           7.0          22.0
# Netherlands                  7.0        10.0          12.0          14.0
# France                       8.0        10.0          12.0          11.0
# Germany                      9.0        10.0          11.0          16.0
# Italy                       10.0        10.0          10.0          20.0
# Canada                      11.0         7.0           6.0          11.0
# Brazil                      12.0         7.0           6.0           8.0
# ...

# %%
above_Mean = above_mean.drop(['RANK', 'TOTAL', 'RANK BY TOTAL'], axis = 1)

# %%
above_Mean
# Out:
#                             GOLD MEDAL  SILVER MEDAL  BRONZE MEDAL
# Team/NOC
# United States of America          39.0          41.0          33.0
# People's Republic of China        38.0          32.0          18.0
# Japan                             27.0          14.0          17.0
# Great Britain                     22.0          21.0          22.0
# ROC                               20.0          28.0          23.0
# Australia                         17.0           7.0          22.0
# Netherlands                       10.0          12.0          14.0
# France                            10.0          12.0          11.0
# Germany                           10.0          11.0          16.0
# Italy                             10.0          10.0          20.0
# Canada                             7.0           6.0          11.0
# Brazil                             7.0           6.0           8.0
# New Zealand                        7.0           6.0           7.0
# ...

# %%
  dfom
# Out:
#                             RANK  GOLD MEDAL  SILVER MEDAL  BRONZE MEDAL  \
# Team/NOC
# United States of America     1.0        39.0          41.0          33.0
# People's Republic of China   2.0        38.0          32.0          18.0
# Japan                        3.0        27.0          14.0          17.0
# Great Britain                4.0        22.0          21.0          22.0
# ROC                          5.0        20.0          28.0          23.0
# ...                          ...         ...           ...           ...
# Ghana                       86.0         0.0           0.0           1.0
# Grenada                     86.0         0.0           0.0           1.0
# Kuwait                      86.0         0.0           0.0           1.0
# Republic of Moldova         86.0         0.0           0.0           1.0
# Syrian Arab Republic        86.0         0.0           0.0           1.0
#
#                             TOTAL  RANK BY TOTAL
# Team/NOC
# ...

# %%
# "GOLD MEDAL","SILVER MEDAL","BRONZE MEDAL","TOTAL"
dfom[(dfom['GOLD MEDAL'] < 3.655914) & (dfom['SILVER MEDAL'] <  3.634409) & (dfom['BRONZE MEDAL'] <  4.322581)]
# Out:
#                           RANK  GOLD MEDAL  SILVER MEDAL  BRONZE MEDAL  TOTAL  \
# Team/NOC
# Croatia                   26.0         3.0           3.0           2.0    8.0
# Islamic Republic of Iran  27.0         3.0           2.0           2.0    7.0
# Belgium                   29.0         3.0           1.0           3.0    7.0
# Bulgaria                  30.0         3.0           1.0           2.0    6.0
# Slovenia                  31.0         3.0           1.0           1.0    5.0
# Uzbekistan                32.0         3.0           0.0           2.0    5.0
# Greece                    36.0         2.0           1.0           1.0    4.0
# Uganda                    36.0         2.0           1.0           1.0    4.0
# Ecuador                   38.0         2.0           1.0           0.0    3.0
# Ireland                   39.0         2.0           0.0           2.0    4.0
# Israel                    39.0         2.0           0.0           2.0    4.0
# ...

# %%
below_mean = dfom[(dfom['GOLD MEDAL'] < 3.655914) & (dfom['SILVER MEDAL'] <  3.634409) & (dfom['BRONZE MEDAL'] <  4.322581)]

# %%
below_Mean = below_mean.drop(['RANK', 'TOTAL', 'RANK BY TOTAL'], axis = 1)

# %%
below_Mean
# Out:
#                           GOLD MEDAL  SILVER MEDAL  BRONZE MEDAL
# Team/NOC
# Croatia                          3.0           3.0           2.0
# Islamic Republic of Iran         3.0           2.0           2.0
# Belgium                          3.0           1.0           3.0
# Bulgaria                         3.0           1.0           2.0
# Slovenia                         3.0           1.0           1.0
# Uzbekistan                       3.0           0.0           2.0
# Greece                           2.0           1.0           1.0
# Uganda                           2.0           1.0           1.0
# Ecuador                          2.0           1.0           0.0
# Ireland                          2.0           0.0           2.0
# Israel                           2.0           0.0           2.0
# Qatar                            2.0           0.0           1.0
# Bahamas                          2.0           0.0           0.0
# ...

# %%
mean = dfom[(dfom['GOLD MEDAL'] == 3.655914) & (dfom['SILVER MEDAL'] ==  3.634409) & (dfom['BRONZE MEDAL'] ==  4.322581)]

# %%
 mean # No country has the average number of medals compared to the 3 types of medals
# Out:
# Empty DataFrame
# Columns: [RANK, GOLD MEDAL, SILVER MEDAL, BRONZE MEDAL, TOTAL, RANK BY TOTAL]
# Index: []

# %%
atleast_one_mean = dfom[(dfom['GOLD MEDAL'] > 3.655914) | (dfom['SILVER MEDAL'] > 3.634409) | (dfom['BRONZE MEDAL'] > 4.322581)]

# %%
atleast_one_mean
# Out:
#                             RANK  GOLD MEDAL  SILVER MEDAL  BRONZE MEDAL  \
# Team/NOC
# United States of America     1.0        39.0          41.0          33.0
# People's Republic of China   2.0        38.0          32.0          18.0
# Japan                        3.0        27.0          14.0          17.0
# Great Britain                4.0        22.0          21.0          22.0
# ROC                          5.0        20.0          28.0          23.0
# Australia                    6.0        17.0           7.0          22.0
# Netherlands                  7.0        10.0          12.0          14.0
# France                       8.0        10.0          12.0          11.0
# Germany                      9.0        10.0          11.0          16.0
# Italy                       10.0        10.0          10.0          20.0
# Canada                      11.0         7.0           6.0          11.0
# Brazil                      12.0         7.0           6.0           8.0
# ...

# %%
atleast_one_Mean = atleast_one_mean.drop(['RANK', 'TOTAL', 'RANK BY TOTAL'], axis = 1)

# %%
atleast_one_Mean
# Out:
#                             GOLD MEDAL  SILVER MEDAL  BRONZE MEDAL
# Team/NOC
# United States of America          39.0          41.0          33.0
# People's Republic of China        38.0          32.0          18.0
# Japan                             27.0          14.0          17.0
# Great Britain                     22.0          21.0          22.0
# ROC                               20.0          28.0          23.0
# Australia                         17.0           7.0          22.0
# Netherlands                       10.0          12.0          14.0
# France                            10.0          12.0          11.0
# Germany                           10.0          11.0          16.0
# Italy                             10.0          10.0          20.0
# Canada                             7.0           6.0          11.0
# Brazil                             7.0           6.0           8.0
# New Zealand                        7.0           6.0           7.0
# ...

# %%
atleast_two_above_mean = dfom[(dfom['GOLD MEDAL'] > 3.655914) & (dfom['SILVER MEDAL'] > 3.634409)]

# %%
atleast_two_above_mean
# Out:
#                             RANK  GOLD MEDAL  SILVER MEDAL  BRONZE MEDAL  \
# Team/NOC
# United States of America     1.0        39.0          41.0          33.0
# People's Republic of China   2.0        38.0          32.0          18.0
# Japan                        3.0        27.0          14.0          17.0
# Great Britain                4.0        22.0          21.0          22.0
# ROC                          5.0        20.0          28.0          23.0
# Australia                    6.0        17.0           7.0          22.0
# Netherlands                  7.0        10.0          12.0          14.0
# France                       8.0        10.0          12.0          11.0
# Germany                      9.0        10.0          11.0          16.0
# Italy                       10.0        10.0          10.0          20.0
# Canada                      11.0         7.0           6.0          11.0
# Brazil                      12.0         7.0           6.0           8.0
# ...

# %%
atleast_two_above_Mean  = atleast_two_above_mean .drop(['RANK', 'TOTAL', 'RANK BY TOTAL'], axis = 1)
atleast_two_above_Mean
# Out:
#                             GOLD MEDAL  SILVER MEDAL  BRONZE MEDAL
# Team/NOC
# United States of America          39.0          41.0          33.0
# People's Republic of China        38.0          32.0          18.0
# Japan                             27.0          14.0          17.0
# Great Britain                     22.0          21.0          22.0
# ROC                               20.0          28.0          23.0
# Australia                         17.0           7.0          22.0
# Netherlands                       10.0          12.0          14.0
# France                            10.0          12.0          11.0
# Germany                           10.0          11.0          16.0
# Italy                             10.0          10.0          20.0
# Canada                             7.0           6.0          11.0
# Brazil                             7.0           6.0           8.0
# New Zealand                        7.0           6.0           7.0
# ...

# %%
atleast_two_below_mean = dfom[(dfom['GOLD MEDAL'] < 3.655914) & (dfom['SILVER MEDAL'] < 3.634409)]

# %%
atleast_two_below_mean
# Out:
#                           RANK  GOLD MEDAL  SILVER MEDAL  BRONZE MEDAL  TOTAL  \
# Team/NOC
# Croatia                   26.0         3.0           3.0           2.0    8.0
# Islamic Republic of Iran  27.0         3.0           2.0           2.0    7.0
# Serbia                    28.0         3.0           1.0           5.0    9.0
# Belgium                   29.0         3.0           1.0           3.0    7.0
# Bulgaria                  30.0         3.0           1.0           2.0    6.0
# ...                        ...         ...           ...           ...    ...
# Ghana                     86.0         0.0           0.0           1.0    1.0
# Grenada                   86.0         0.0           0.0           1.0    1.0
# Kuwait                    86.0         0.0           0.0           1.0    1.0
# Republic of Moldova       86.0         0.0           0.0           1.0    1.0
# Syrian Arab Republic      86.0         0.0           0.0           1.0    1.0
#
# ...

# %%
atleast_two_below_Mean  = atleast_two_below_mean .drop(['RANK', 'TOTAL', 'RANK BY TOTAL'], axis = 1)
atleast_two_below_Mean
# Out:
#                           GOLD MEDAL  SILVER MEDAL  BRONZE MEDAL
# Team/NOC
# Croatia                          3.0           3.0           2.0
# Islamic Republic of Iran         3.0           2.0           2.0
# Serbia                           3.0           1.0           5.0
# Belgium                          3.0           1.0           3.0
# Bulgaria                         3.0           1.0           2.0
# ...                              ...           ...           ...
# Ghana                            0.0           0.0           1.0
# Grenada                          0.0           0.0           1.0
# Kuwait                           0.0           0.0           1.0
# Republic of Moldova              0.0           0.0           1.0
# Syrian Arab Republic             0.0           0.0           1.0
#
# [64 rows x 3 columns]

# %%
atleast_two_below_Mean.head(20)
# Out:
#                           GOLD MEDAL  SILVER MEDAL  BRONZE MEDAL
# Team/NOC
# Croatia                          3.0           3.0           2.0
# Islamic Republic of Iran         3.0           2.0           2.0
# Serbia                           3.0           1.0           5.0
# Belgium                          3.0           1.0           3.0
# Bulgaria                         3.0           1.0           2.0
# Slovenia                         3.0           1.0           1.0
# Uzbekistan                       3.0           0.0           2.0
# Turkey                           2.0           2.0           9.0
# Greece                           2.0           1.0           1.0
# Uganda                           2.0           1.0           1.0
# Ecuador                          2.0           1.0           0.0
# Ireland                          2.0           0.0           2.0
# Israel                           2.0           0.0           2.0
# ...

# %% [markdown]
# # Top 10 countries by total number of medals

# %%
dfom.head(10)
# Out:
#                             RANK  GOLD MEDAL  SILVER MEDAL  BRONZE MEDAL  \
# Team/NOC
# United States of America     1.0        39.0          41.0          33.0
# People's Republic of China   2.0        38.0          32.0          18.0
# Japan                        3.0        27.0          14.0          17.0
# Great Britain                4.0        22.0          21.0          22.0
# ROC                          5.0        20.0          28.0          23.0
# Australia                    6.0        17.0           7.0          22.0
# Netherlands                  7.0        10.0          12.0          14.0
# France                       8.0        10.0          12.0          11.0
# Germany                      9.0        10.0          11.0          16.0
# Italy                       10.0        10.0          10.0          20.0
#
#                             TOTAL  RANK BY TOTAL
# Team/NOC
# United States of America    113.0            1.0
# ...

# %%
dfomtop10_by_value_of_medals  = dfom.head(10).drop(["RANK","GOLD MEDAL","SILVER MEDAL","BRONZE MEDAL","RANK BY TOTAL"], axis = 1)

# %%
dfomtop10_by_value_of_medals # Ranking by value (not total quantity) of medals won by the 10 First Nations.
# Out:
#                             TOTAL
# Team/NOC
# United States of America    113.0
# People's Republic of China   88.0
# Japan                        58.0
# Great Britain                65.0
# ROC                          71.0
# Australia                    46.0
# Netherlands                  36.0
# France                       33.0
# Germany                      37.0
# Italy                        40.0

# %%
# Ranking by total quantity (not by value) of medals won by each of the 10 First Nations.
# df.sort_values(['a', 'b'], ascending=[True, False])

dfomtop10_by_quantity_of_medals   = dfomtop10_by_value_of_medals .sort_values(["TOTAL"], ascending=[False])
dfomtop10_by_quantity_of_medals
# Out:
#                             TOTAL
# Team/NOC
# United States of America    113.0
# People's Republic of China   88.0
# ROC                          71.0
# Great Britain                65.0
# Japan                        58.0
# Australia                    46.0
# Italy                        40.0
# Germany                      37.0
# Netherlands                  36.0
# France                       33.0

# %% [markdown]
# # Visualization of the Top 10 countries by total number of medals

# %%
dfomtop10_by_quantity_of_medals.plot(kind = 'bar',color ='b',figsize = (15,7))

plt.title("Top 10 countries by total number of medals")

plt.xlabel("Team/NOC")

plt.ylabel("Total")

plt.show()

# %% [markdown]
# # Visualization of the Top 10 countries by Value of medals

# %%
dfomtop10_by_value_of_medals.plot(kind = 'bar',color ='g',figsize = (15,7))

plt.title("Top 10 countries by value of medals")

plt.xlabel("Team/NOC")

plt.ylabel("Total")

plt.show()

# %% [markdown]
# # The last 10 countries by total number of medals

# %%
dfom.tail(10)
# Out:
#                       RANK  GOLD MEDAL  SILVER MEDAL  BRONZE MEDAL  TOTAL  \
# Team/NOC
# Mexico                84.0         0.0           0.0           4.0    4.0
# Finland               85.0         0.0           0.0           2.0    2.0
# Botswana              86.0         0.0           0.0           1.0    1.0
# Burkina Faso          86.0         0.0           0.0           1.0    1.0
# Côte d'Ivoire         86.0         0.0           0.0           1.0    1.0
# Ghana                 86.0         0.0           0.0           1.0    1.0
# Grenada               86.0         0.0           0.0           1.0    1.0
# Kuwait                86.0         0.0           0.0           1.0    1.0
# Republic of Moldova   86.0         0.0           0.0           1.0    1.0
# Syrian Arab Republic  86.0         0.0           0.0           1.0    1.0
#
#                       RANK BY TOTAL
# Team/NOC
# Mexico                         47.0
# Finland                        66.0
# ...

# %%
dfomlast10_by_value_of_medals  = dfom.tail(10).drop(["RANK","GOLD MEDAL","SILVER MEDAL","BRONZE MEDAL","RANK BY TOTAL"], axis = 1)
dfomlast10_by_value_of_medals
# Out:
#                       TOTAL
# Team/NOC
# Mexico                  4.0
# Finland                 2.0
# Botswana                1.0
# Burkina Faso            1.0
# Côte d'Ivoire           1.0
# Ghana                   1.0
# Grenada                 1.0
# Kuwait                  1.0
# Republic of Moldova     1.0
# Syrian Arab Republic    1.0

# %%
dfomlast10_by_quantity_of_medals  = dfomlast10_by_value_of_medals.sort_values(["TOTAL"], ascending=[False])
dfomlast10_by_quantity_of_medals
# Out:
#                       TOTAL
# Team/NOC
# Mexico                  4.0
# Finland                 2.0
# Botswana                1.0
# Burkina Faso            1.0
# Côte d'Ivoire           1.0
# Ghana                   1.0
# Grenada                 1.0
# Kuwait                  1.0
# Republic of Moldova     1.0
# Syrian Arab Republic    1.0

# %% [markdown]
# # Visualization of the last 10 countries by total number of medals = Visualization of the last 10 countries by total value of medals

# %%
dfomlast10_by_quantity_of_medals .plot(kind = 'bar',color ='y',figsize = (15,7))

plt.title("Last 10 countries by total number of medals")

plt.xlabel("Team/NOC")

plt.ylabel("Total")

plt.show()

# %% [markdown]
# # Analyze the data in relation to the different continents that were present at the Tokyo 2020 Olympic Games

# %%
import numpy as np
import pandas as pdsa
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import openpyxl

# %%
dfosa = pdsa.read_excel('/content/drive/MyDrive/Data_Engineering/Tokyo Olympics 2020(2021)/Olympic Medal Count 2020.xlsx',
                    sheet_name='South American countries')

# %%
dfosa
# Out:
#     COUNTRIES  ATHLETES  GOLD  SILVER  BRONZE
# 0   Argentina     174.0   0.0     1.0     2.0
# 1       Aruba       3.0   0.0     0.0     0.0
# 2     Bolivia       5.0   0.0     0.0     0.0
# 3      Brazil     301.0   7.0     6.0     8.0
# 4       Chile      57.0   0.0     0.0     0.0
# 5    Colombia      70.0   0.0     4.0     1.0
# 6     Ecuador      48.0   2.0     1.0     0.0
# 7      Guyana       7.0   0.0     0.0     0.0
# 8    Paraguay       8.0   0.0     0.0     0.0
# 9        Peru      35.0   0.0     0.0     0.0
# 10   Suriname       3.0   0.0     0.0     0.0
# 11    Uruguay      11.0   0.0     0.0     0.0
# 12  Venezuela      44.0   1.0     3.0     0.0

# %%
dfosa.set_index('COUNTRIES', inplace=True)

# %%
dfosa
# Out:
#            ATHLETES  GOLD  SILVER  BRONZE
# COUNTRIES
# Argentina     174.0   0.0     1.0     2.0
# Aruba           3.0   0.0     0.0     0.0
# Bolivia         5.0   0.0     0.0     0.0
# Brazil        301.0   7.0     6.0     8.0
# Chile          57.0   0.0     0.0     0.0
# Colombia       70.0   0.0     4.0     1.0
# Ecuador        48.0   2.0     1.0     0.0
# Guyana          7.0   0.0     0.0     0.0
# Paraguay        8.0   0.0     0.0     0.0
# Peru           35.0   0.0     0.0     0.0
# Suriname        3.0   0.0     0.0     0.0
# Uruguay        11.0   0.0     0.0     0.0
# Venezuela      44.0   1.0     3.0     0.0

# %%
dfosa.columns =list(map( str,dfosa.columns))

# %%
dfosa
# Out:
#            ATHLETES  GOLD  SILVER  BRONZE
# COUNTRIES
# Argentina     174.0   0.0     1.0     2.0
# Aruba           3.0   0.0     0.0     0.0
# Bolivia         5.0   0.0     0.0     0.0
# Brazil        301.0   7.0     6.0     8.0
# Chile          57.0   0.0     0.0     0.0
# Colombia       70.0   0.0     4.0     1.0
# Ecuador        48.0   2.0     1.0     0.0
# Guyana          7.0   0.0     0.0     0.0
# Paraguay        8.0   0.0     0.0     0.0
# Peru           35.0   0.0     0.0     0.0
# Suriname        3.0   0.0     0.0     0.0
# Uruguay        11.0   0.0     0.0     0.0
# Venezuela      44.0   1.0     3.0     0.0

# %%
dfosa.loc['Total_South America'] = pdsa.Series([dfosa['ATHLETES'].sum(),dfosa['GOLD'].sum(),dfosa['SILVER'].sum(),dfosa['BRONZE'].sum()], index = ["ATHLETES","GOLD","SILVER","BRONZE"])

# %%
dfosa
# Out:
#                      ATHLETES  GOLD  SILVER  BRONZE
# COUNTRIES
# Argentina               174.0   0.0     1.0     2.0
# Aruba                     3.0   0.0     0.0     0.0
# Bolivia                   5.0   0.0     0.0     0.0
# Brazil                  301.0   7.0     6.0     8.0
# Chile                    57.0   0.0     0.0     0.0
# Colombia                 70.0   0.0     4.0     1.0
# Ecuador                  48.0   2.0     1.0     0.0
# Guyana                    7.0   0.0     0.0     0.0
# Paraguay                  8.0   0.0     0.0     0.0
# Peru                     35.0   0.0     0.0     0.0
# Suriname                  3.0   0.0     0.0     0.0
# Uruguay                  11.0   0.0     0.0     0.0
# Venezuela                44.0   1.0     3.0     0.0
# Total_South America     766.0  10.0    15.0    11.0

# %%
import numpy as np
import pandas as pdaf
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import openpyxl

# %%
dfoaf = pdaf.read_excel('/content/drive/MyDrive/Data_Engineering/Tokyo Olympics 2020(2021)/Olympic Medal Count 2020.xlsx',
                    sheet_name='African countries')

# %%
dfoaf
# Out:
#                            COUNTRIES  ATHLETES  GOLD  SILVER  BRONZE
# 0                            Algeria      44.0   0.0     0.0     0.0
# 1                             Angola      20.0   0.0     0.0     0.0
# 2                              Benin       7.0   0.0     0.0     0.0
# 3                           Botswana      13.0   0.0     0.0     1.0
# 4                       Burkina Faso       7.0   0.0     0.0     1.0
# 5                            Burundi       6.0   0.0     0.0     0.0
# 6                           Cameroon      12.0   0.0     0.0     0.0
# 7                         Cape Verde       6.0   0.0     0.0     0.0
# 8           Central African Republic       2.0   0.0     0.0     0.0
# 9                               Chad       3.0   0.0     0.0     0.0
# 10                           Comoros       3.0   0.0     0.0     0.0
# 11  Democratic Republic of the Congo       7.0   0.0     0.0     0.0
# 12                          Djibouti       4.0   0.0     0.0     0.0
# ...

# %%
dfoaf.set_index('COUNTRIES', inplace=True)

# %%
dfoaf
# Out:
#                                   ATHLETES  GOLD  SILVER  BRONZE
# COUNTRIES
# Algeria                               44.0   0.0     0.0     0.0
# Angola                                20.0   0.0     0.0     0.0
# Benin                                  7.0   0.0     0.0     0.0
# Botswana                              13.0   0.0     0.0     1.0
# Burkina Faso                           7.0   0.0     0.0     1.0
# Burundi                                6.0   0.0     0.0     0.0
# Cameroon                              12.0   0.0     0.0     0.0
# Cape Verde                             6.0   0.0     0.0     0.0
# Central African Republic               2.0   0.0     0.0     0.0
# Chad                                   3.0   0.0     0.0     0.0
# Comoros                                3.0   0.0     0.0     0.0
# Democratic Republic of the Congo       7.0   0.0     0.0     0.0
# Djibouti                               4.0   0.0     0.0     0.0
# ...

# %%
dfoaf.loc['Total_Africa'] = pdaf.Series([dfoaf['ATHLETES'].sum(),dfoaf['GOLD'].sum(),dfoaf['SILVER'].sum(),dfoaf['BRONZE'].sum()], index = ["ATHLETES","GOLD","SILVER","BRONZE"])

# %%
dfoaf
# Out:
#                                   ATHLETES  GOLD  SILVER  BRONZE
# COUNTRIES
# Algeria                               44.0   0.0     0.0     0.0
# Angola                                20.0   0.0     0.0     0.0
# Benin                                  7.0   0.0     0.0     0.0
# Botswana                              13.0   0.0     0.0     1.0
# Burkina Faso                           7.0   0.0     0.0     1.0
# Burundi                                6.0   0.0     0.0     0.0
# Cameroon                              12.0   0.0     0.0     0.0
# Cape Verde                             6.0   0.0     0.0     0.0
# Central African Republic               2.0   0.0     0.0     0.0
# Chad                                   3.0   0.0     0.0     0.0
# Comoros                                3.0   0.0     0.0     0.0
# Democratic Republic of the Congo       7.0   0.0     0.0     0.0
# Djibouti                               4.0   0.0     0.0     0.0
# ...

# %%
import numpy as np
import pandas as pdoc
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import openpyxl

# %%
dfooc = pdoc.read_excel('/content/drive/MyDrive/Data_Engineering/Tokyo Olympics 2020(2021)/Olympic Medal Count 2020.xlsx',
                    sheet_name='Oceanian countries')

# %%
dfooc.set_index('COUNTRIES', inplace=True)

# %%
dfooc.loc['Total_Oceania'] = pdoc.Series([dfooc['ATHLETES'].sum(),dfooc['GOLD'].sum(),dfooc['SILVER'].sum(),dfooc['BRONZE'].sum()], index = ["ATHLETES","GOLD","SILVER","BRONZE"])

# %%
dfooc
# Out:
#                               ATHLETES  GOLD  SILVER  BRONZE
# COUNTRIES
# American Samoa                     6.0   0.0     0.0     0.0
# Australia                        478.0  17.0     7.0    22.0
# Cook Islands                       6.0   0.0     0.0     0.0
# Federal States of Micronesia       3.0   0.0     0.0     0.0
# Fiji                              30.0   1.0     0.0     1.0
# Guam                               5.0   0.0     0.0     0.0
# Kiribati                           3.0   0.0     0.0     0.0
# Marshall Islands                   2.0   0.0     0.0     0.0
# Nauru                              2.0   0.0     0.0     0.0
# New Zealand                      223.0   7.0     6.0     7.0
# Palau                              3.0   0.0     0.0     0.0
# Papua New Guinea                   8.0   0.0     0.0     0.0
# Samoa                              8.0   0.0     0.0     0.0
# Solomon Islands                    3.0   0.0     0.0     0.0
# ...

# %%
dfooc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, American Samoa to Total_Oceania
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ATHLETES  18 non-null     float64
#  1   GOLD      18 non-null     float64
#  2   SILVER    18 non-null     float64
#  3   BRONZE    18 non-null     float64
# dtypes: float64(4)
# memory usage: 720.0+ bytes

# %%
import numpy as np
import pandas as pdasian
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import openpyxl

# %%
dfoasian = pdasian.read_excel('/content/drive/MyDrive/Data_Engineering/Tokyo Olympics 2020(2021)/Olympic Medal Count 2020.xlsx',
                    sheet_name='Asian countries')

# %%
dfoasian
# Out:
#                COUNTRIES  ATHLETES  GOLD  SILVER  BRONZE
# 0            Afghanistan       5.0   0.0     0.0     0.0
# 1                Armenia      17.0   0.0     2.0     2.0
# 2             Azerbaijan      44.0   0.0     3.0     4.0
# 3                Bahrain      32.0   0.0     1.0     0.0
# 4             Bangladesh       6.0   0.0     0.0     0.0
# 5                 Bhutan       4.0   0.0     0.0     0.0
# 6                 Brunei       2.0   0.0     0.0     0.0
# 7               Cambodia       3.0   0.0     0.0     0.0
# 8                  China     406.0  38.0    32.0    18.0
# 9                 Cyprus      15.0   0.0     0.0     0.0
# 10            East Timor       3.0   0.0     0.0     0.0
# 11             Hong Kong      42.0   1.0     2.0     3.0
# 12                 India     127.0   1.0     2.0     4.0
# 13             Indonesia      28.0   1.0     1.0     3.0
# 14                  Iran      66.0   3.0     2.0     2.0
# ...

# %%
dfoasian.set_index('COUNTRIES', inplace=True)

# %%
dfoasian
# Out:
#                       ATHLETES  GOLD  SILVER  BRONZE
# COUNTRIES
# Afghanistan                5.0   0.0     0.0     0.0
# Armenia                   17.0   0.0     2.0     2.0
# Azerbaijan                44.0   0.0     3.0     4.0
# Bahrain                   32.0   0.0     1.0     0.0
# Bangladesh                 6.0   0.0     0.0     0.0
# Bhutan                     4.0   0.0     0.0     0.0
# Brunei                     2.0   0.0     0.0     0.0
# Cambodia                   3.0   0.0     0.0     0.0
# China                    406.0  38.0    32.0    18.0
# Cyprus                    15.0   0.0     0.0     0.0
# East Timor                 3.0   0.0     0.0     0.0
# Hong Kong                 42.0   1.0     2.0     3.0
# India                    127.0   1.0     2.0     4.0
# Indonesia                 28.0   1.0     1.0     3.0
# Iran                      66.0   3.0     2.0     2.0
# Iraq                       4.0   0.0     0.0     0.0
# ...

# %%
dfoasian.loc['Total_Asia'] = pdasian.Series([dfoasian['ATHLETES'].sum(),dfoasian['GOLD'].sum(),dfoasian['SILVER'].sum(),dfoasian['BRONZE'].sum()], index = ["ATHLETES","GOLD","SILVER","BRONZE"])

# %%
dfoasian
# Out:
#                       ATHLETES  GOLD  SILVER  BRONZE
# COUNTRIES
# Afghanistan                5.0   0.0     0.0     0.0
# Armenia                   17.0   0.0     2.0     2.0
# Azerbaijan                44.0   0.0     3.0     4.0
# Bahrain                   32.0   0.0     1.0     0.0
# Bangladesh                 6.0   0.0     0.0     0.0
# Bhutan                     4.0   0.0     0.0     0.0
# Brunei                     2.0   0.0     0.0     0.0
# Cambodia                   3.0   0.0     0.0     0.0
# China                    406.0  38.0    32.0    18.0
# Cyprus                    15.0   0.0     0.0     0.0
# East Timor                 3.0   0.0     0.0     0.0
# Hong Kong                 42.0   1.0     2.0     3.0
# India                    127.0   1.0     2.0     4.0
# Indonesia                 28.0   1.0     1.0     3.0
# Iran                      66.0   3.0     2.0     2.0
# Iraq                       4.0   0.0     0.0     0.0
# ...

# %%
import numpy as np
import pandas as pdeuro
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import openpyxl

# %%
dfoeuro = pdeuro.read_excel('/content/drive/MyDrive/Data_Engineering/Tokyo Olympics 2020(2021)/Olympic Medal Count 2020.xlsx',
                    sheet_name='European countries')

# %%
dfoeuro
# Out:
#                  COUNTRIES  ATHLETES  GOLD  SILVER  BRONZE
# 0                  Albania       9.0   0.0     0.0     0.0
# 1                  Andorra       2.0   0.0     0.0     0.0
# 2                  Austria      60.0   1.0     1.0     5.0
# 3                  Belarus     101.0   1.0     3.0     3.0
# 4                  Belgium     121.0   3.0     1.0     3.0
# 5   Bosnia and Herzegovina       7.0   0.0     0.0     0.0
# 6                 Bulgaria      42.0   3.0     1.0     2.0
# 7                  Croatia      59.0   3.0     3.0     2.0
# 8           Czech Republic     115.0   4.0     4.0     3.0
# 9                  Denmark     107.0   3.0     4.0     4.0
# 10                 Estonia      33.0   1.0     0.0     1.0
# 11                 Finland      29.0   0.0     0.0     2.0
# 12                  France     398.0  10.0    12.0    11.0
# 13                 Georgia      35.0   2.0     5.0     1.0
# 14                 Germany     425.0  10.0    11.0    16.0
# ...

# %%
dfoeuro.set_index('COUNTRIES', inplace=True)

# %%
dfoeuro
# Out:
#                         ATHLETES  GOLD  SILVER  BRONZE
# COUNTRIES
# Albania                      9.0   0.0     0.0     0.0
# Andorra                      2.0   0.0     0.0     0.0
# Austria                     60.0   1.0     1.0     5.0
# Belarus                    101.0   1.0     3.0     3.0
# Belgium                    121.0   3.0     1.0     3.0
# Bosnia and Herzegovina       7.0   0.0     0.0     0.0
# Bulgaria                    42.0   3.0     1.0     2.0
# Croatia                     59.0   3.0     3.0     2.0
# Czech Republic             115.0   4.0     4.0     3.0
# Denmark                    107.0   3.0     4.0     4.0
# Estonia                     33.0   1.0     0.0     1.0
# Finland                     29.0   0.0     0.0     2.0
# France                     398.0  10.0    12.0    11.0
# Georgia                     35.0   2.0     5.0     1.0
# Germany                    425.0  10.0    11.0    16.0
# Great Britain              376.0  22.0    21.0    22.0
# ...

# %%
dfoeuro.loc['Total_Europe'] = pdeuro.Series([dfoeuro['ATHLETES'].sum(),dfoeuro['GOLD'].sum(),dfoeuro['SILVER'].sum(),dfoeuro['BRONZE'].sum()], index = ["ATHLETES","GOLD","SILVER","BRONZE"])

# %%
dfoeuro
# Out:
#                         ATHLETES   GOLD  SILVER  BRONZE
# COUNTRIES
# Albania                      9.0    0.0     0.0     0.0
# Andorra                      2.0    0.0     0.0     0.0
# Austria                     60.0    1.0     1.0     5.0
# Belarus                    101.0    1.0     3.0     3.0
# Belgium                    121.0    3.0     1.0     3.0
# Bosnia and Herzegovina       7.0    0.0     0.0     0.0
# Bulgaria                    42.0    3.0     1.0     2.0
# Croatia                     59.0    3.0     3.0     2.0
# Czech Republic             115.0    4.0     4.0     3.0
# Denmark                    107.0    3.0     4.0     4.0
# Estonia                     33.0    1.0     0.0     1.0
# Finland                     29.0    0.0     0.0     2.0
# France                     398.0   10.0    12.0    11.0
# Georgia                     35.0    2.0     5.0     1.0
# Germany                    425.0   10.0    11.0    16.0
# Great Britain              376.0   22.0    21.0    22.0
# ...

# %%
import numpy as np
import pandas as pdnordAme
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import openpyxl

# %%
dfonordAme = pdnordAme.read_excel('/content/drive/MyDrive/Data_Engineering/Tokyo Olympics 2020(2021)/Olympic Medal Count 2020.xlsx',
                    sheet_name='North American countries')

# %%
dfonordAme
# Out:
#                            COUNTRIES  ATHLETES  GOLD  SILVER  BRONZE
# 0                Antigua and Barbuda       6.0   0.0     0.0     0.0
# 1                            Bahamas      16.0   2.0     0.0     0.0
# 2                           Barbados       8.0   0.0     0.0     0.0
# 3                             Belize       3.0   0.0     0.0     0.0
# 4                            Bermuda       2.0   1.0     0.0     0.0
# 5                            Bolivia       5.0   0.0     0.0     0.0
# 6             British Virgin Islands       3.0   0.0     0.0     0.0
# 7                             Canada     371.0   7.0     6.0    11.0
# 8                     Cayman Islands       5.0   0.0     0.0     0.0
# 9                         Costa Rica      14.0   0.0     0.0     0.0
# 10                              Cuba      70.0   7.0     3.0     5.0
# 11                          Dominica       2.0   0.0     0.0     0.0
# 12                Dominican Republic      62.0   0.0     3.0     2.0
# ...

# %%
dfonordAme.set_index('COUNTRIES', inplace=True)

# %%
dfonordAme
# Out:
#                                   ATHLETES  GOLD  SILVER  BRONZE
# COUNTRIES
# Antigua and Barbuda                    6.0   0.0     0.0     0.0
# Bahamas                               16.0   2.0     0.0     0.0
# Barbados                               8.0   0.0     0.0     0.0
# Belize                                 3.0   0.0     0.0     0.0
# Bermuda                                2.0   1.0     0.0     0.0
# Bolivia                                5.0   0.0     0.0     0.0
# British Virgin Islands                 3.0   0.0     0.0     0.0
# Canada                               371.0   7.0     6.0    11.0
# Cayman Islands                         5.0   0.0     0.0     0.0
# Costa Rica                            14.0   0.0     0.0     0.0
# Cuba                                  70.0   7.0     3.0     5.0
# Dominica                               2.0   0.0     0.0     0.0
# Dominican Republic                    62.0   0.0     3.0     2.0
# ...

# %%
dfonordAme.loc['Total_North America'] = pdnordAme.Series([dfonordAme['ATHLETES'].sum(),dfonordAme['GOLD'].sum(),dfonordAme['SILVER'].sum(),dfonordAme['BRONZE'].sum()], index = ["ATHLETES","GOLD","SILVER","BRONZE"])

# %%
dfonordAme
# Out:
#                                   ATHLETES  GOLD  SILVER  BRONZE
# COUNTRIES
# Antigua and Barbuda                    6.0   0.0     0.0     0.0
# Bahamas                               16.0   2.0     0.0     0.0
# Barbados                               8.0   0.0     0.0     0.0
# Belize                                 3.0   0.0     0.0     0.0
# Bermuda                                2.0   1.0     0.0     0.0
# Bolivia                                5.0   0.0     0.0     0.0
# British Virgin Islands                 3.0   0.0     0.0     0.0
# Canada                               371.0   7.0     6.0    11.0
# Cayman Islands                         5.0   0.0     0.0     0.0
# Costa Rica                            14.0   0.0     0.0     0.0
# Cuba                                  70.0   7.0     3.0     5.0
# Dominica                               2.0   0.0     0.0     0.0
# Dominican Republic                    62.0   0.0     3.0     2.0
# ...

# %%
dfonordAme.iloc[28, 0:4]
# Out:
# ATHLETES    1544.0
# GOLD          61.0
# SILVER        54.0
# BRONZE        60.0
# Name: Total_North America, dtype: float64

# %%
dfonordAme.iloc[[28]]
# Out:
#                      ATHLETES  GOLD  SILVER  BRONZE
# COUNTRIES
# Total_North America    1544.0  61.0    54.0    60.0

# %%
dfonordAme1 = dfonordAme.iloc[[28]]

# %%
dfonordAme1
# Out:
#                      ATHLETES  GOLD  SILVER  BRONZE
# COUNTRIES
# Total_North America    1544.0  61.0    54.0    60.0

# %%
dfoeuro1 = dfoeuro.iloc[[45]]

# %%
dfoeuro1
# Out:
#               ATHLETES   GOLD  SILVER  BRONZE
# COUNTRIES
# Total_Europe    4822.0  140.0   162.0   185.0

# %%
dfoasian1 = dfoasian.iloc[[48]]

# %%
dfoasian1
# Out:
#             ATHLETES  GOLD  SILVER  BRONZE
# COUNTRIES
# Total_Asia    2334.0  90.0    78.0   101.0

# %%
dfooc1 = dfooc.iloc[[17]]

# %%
dfooc1
# Out:
#                ATHLETES  GOLD  SILVER  BRONZE
# COUNTRIES
# Total_Oceania     791.0  25.0    13.0    30.0

# %%
dfoaf1 = dfoaf.iloc[[54]]

# %%
 dfoaf1
# Out:
#               ATHLETES  GOLD  SILVER  BRONZE
# COUNTRIES
# Total_Africa     984.0  11.0    12.0    14.0

# %%
import pandas as pdcon
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_continents = pdcon.read_excel('/content/drive/MyDrive/Data_Engineering/Tokyo Olympics 2020(2021)/Olympic Medal Count 2020.xlsx',
                    sheet_name='Continents Medals')

# %%
df_continents
# Out:
#       CONTINENTS  ATHLETES   GOLD  SILVER  BRONZE
# 0  South America     766.0   10.0    15.0    11.0
# 1         Africa     984.0   11.0    12.0    14.0
# 2        Oceania     791.0   25.0    13.0    30.0
# 3           Asia    2334.0   90.0    78.0   101.0
# 4         Europe    4822.0  140.0   162.0   185.0
# 5  North America    1544.0   61.0    54.0    60.0

# %%
df_continents.set_index('CONTINENTS', inplace=True)

# %%
df_continents
# Out:
#                ATHLETES   GOLD  SILVER  BRONZE
# CONTINENTS
# South America     766.0   10.0    15.0    11.0
# Africa            984.0   11.0    12.0    14.0
# Oceania           791.0   25.0    13.0    30.0
# Asia             2334.0   90.0    78.0   101.0
# Europe           4822.0  140.0   162.0   185.0
# North America    1544.0   61.0    54.0    60.0

# %%
df_continents['TOTAL_MEDAL_BY_CONTINENT'] = df_continents.iloc[:, 1:].sum(axis = 1)
df_continents
# Out:
#                ATHLETES   GOLD  SILVER  BRONZE  TOTAL_MEDAL_BY_CONTINENT
# CONTINENTS
# South America     766.0   10.0    15.0    11.0                      36.0
# Africa            984.0   11.0    12.0    14.0                      37.0
# Oceania           791.0   25.0    13.0    30.0                      68.0
# Asia             2334.0   90.0    78.0   101.0                     269.0
# Europe           4822.0  140.0   162.0   185.0                     487.0
# North America    1544.0   61.0    54.0    60.0                     175.0

# %%
Continents = df_continents.reset_index()
Continents
# Out:
#       CONTINENTS  ATHLETES   GOLD  SILVER  BRONZE  TOTAL_MEDAL_BY_CONTINENT
# 0  South America     766.0   10.0    15.0    11.0                      36.0
# 1         Africa     984.0   11.0    12.0    14.0                      37.0
# 2        Oceania     791.0   25.0    13.0    30.0                      68.0
# 3           Asia    2334.0   90.0    78.0   101.0                     269.0
# 4         Europe    4822.0  140.0   162.0   185.0                     487.0
# 5  North America    1544.0   61.0    54.0    60.0                     175.0

# %%
CONT = pw.Pywedge_Charts(Continents, c=None, y="CONTINENTS") 
# For Visualization
chart = CONT.make_charts()
# Out:
# /usr/local/lib/python3.7/dist-packages/pywedge/pywedge.py:27: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# HTML(value='<h2>Pywedge Make_Charts </h2>')
# ...

# %% [markdown]
# # Visualization of the Total Gold of medals won by Continent

# %%
df_continents["GOLD"].plot(kind = 'bar',color ='y',figsize = (15,7))
plt.title("Total Gold of medals won by Continent")

plt.xlabel("CONTINENTS")

plt.ylabel("TOTAL GOLD MEDALS")

plt.show()

# %% [markdown]
# # Percentage of Total gold medals won by Continent

# %%
df_continents['GOLD'].plot( kind = 'pie', figsize = (18,9),autopct ='%1.1f%%')
plt.title("Percentage of Total gold medals won by Continent")

plt.xlabel("")

plt.ylabel("")

plt.show()

# %% [markdown]
# # Percentage of Total Silver medals won by Continent

# %%
df_continents['SILVER'].plot( kind = 'pie', figsize = (18,9),autopct ='%1.1f%%')
plt.title("Percentage of Total Silver medals won by Continent")

plt.xlabel("")

plt.ylabel("")

plt.show()

# %% [markdown]
# # Percentage of Total Bronze medals won by Continent

# %%
df_continents['BRONZE'].plot( kind = 'pie', figsize = (18,9),autopct ='%1.1f%%')
plt.title("Percentage of Total Bronze medals won by Continent")

plt.xlabel("")

plt.ylabel("")

plt.show()

# %% [markdown]
# # PERCENTAGE OF TOTAL ATHLETES PER CONTINENT

# %%
df_continents['ATHLETES'].plot( kind = 'pie', figsize = (18,9),autopct ='%1.1f%%')
plt.title("PERCENTAGE OF TOTAL ATHLETES PER CONTINENT")

plt.xlabel("")

plt.ylabel("")

plt.show()

# %% [markdown]
# # Descriptive Statistics

# %%
df_continents.describe()
# Out:
#           ATHLETES        GOLD      SILVER      BRONZE  \
# count     6.000000    6.000000    6.000000    6.000000
# mean   1873.500000   56.166667   55.666667   66.833333
# std    1562.296739   51.650428   58.633324   66.996766
# min     766.000000   10.000000   12.000000   11.000000
# 25%     839.250000   14.500000   13.500000   18.000000
# 50%    1264.000000   43.000000   34.500000   45.000000
# 75%    2136.500000   82.750000   72.000000   90.750000
# max    4822.000000  140.000000  162.000000  185.000000
#
#        TOTAL_MEDAL_BY_CONTINENT
# count                  6.000000
# mean                 178.666667
# std                  176.586145
# min                   36.000000
# 25%                   44.750000
# 50%                  121.500000
# 75%                  245.500000
# max                  487.000000

# %% [markdown]
# # Statistical and graphical interpretation

# %% [markdown]
# # On average, a continent sent 1873 athletes and won 56.16 gold medals, 55.66silver medals and 66.83 bronze medals. ATHLETES, GOLDS, SILVER, BRONZE have high standard deviation

# %% [markdown]
# # TOTAL ATHLETES BY CONTINENT

# %%
df_continents["ATHLETES"].plot(kind = 'bar',color ='y',figsize = (9,6))

plt.title("TOTAL ATHLETES BY CONTINENT")

plt.xlabel("CONTINENTS")

plt.ylabel("NUMBER OF ATHLETES")

plt.show()

# %% [markdown]
# # SCATTER OF NUMBER OF GOLD MEDAL BY NUMBER OF ATHLETES

# %%
df_continents.plot(kind = "scatter", x = "ATHLETES", y = "GOLD",figsize = (10,6), color = "orange")
plt.xlabel('NUMBER OF ATHLETES')
plt.ylabel('NUMBER OF GOLD MEDAL')
plt.xticks(rotation = 90)
plt.title('SCATTER OF NUMBER OF GOLD MEDAL BY NUMBER OF ATHLETES')
plt.show()

# %% [markdown]
# # SCATTER OF NUMBER OF SILVER MEDAL BY NUMBER OF ATHLETES

# %%
df_continents.plot(kind = "scatter", x = "ATHLETES", y = "SILVER",figsize = (10,6), color = "k")
plt.xlabel('NUMBER OF ATHLETES')
plt.ylabel('NUMBER OF SILVER MEDAL')
plt.xticks(rotation = 90)
plt.title('SCATTER OF NUMBER OF SILVER MEDAL BY NUMBER OF ATHLETES')
plt.show()

# %% [markdown]
# # SCATTER OF NUMBER OF BRONZE MEDAL BY NUMBER OF ATHLETES

# %%
df_continents.plot(kind = "scatter", x = "ATHLETES", y = "BRONZE",figsize = (10,6), color = "green")
plt.xlabel('NUMBER OF ATHLETES')
plt.ylabel('NUMBER OF BRONZE MEDAL')
plt.xticks(rotation = 90)
plt.title('SCATTER OF NUMBER OF BRONZE MEDAL BY NUMBER OF ATHLETES')
plt.show()

# %% [markdown]
# # Find the correlation between the number of athletes and the total number of gold,silver,and bronze medals by continent.

# %%
corr_Athlete_Gold = df_continents["GOLD"].corr(df_continents["ATHLETES"])

# %%
corr_Athlete_Gold
# Out:
# 0.957238150372163

# %%
corr_Athlete_Gold1 = df_continents["ATHLETES"].corr(df_continents["GOLD"])

# %%
corr_Athlete_Gold1
# Out:
# 0.957238150372163

# %%
corr_Athlete_Silver = df_continents["SILVER"].corr(df_continents["ATHLETES"])

# %%
corr_Athlete_Silver
# Out:
# 0.9921634293063021

# %%
corr_Athlete_bronze = df_continents["BRONZE"].corr(df_continents["ATHLETES"])

# %%
corr_Athlete_bronze
# Out:
# 0.9842519574746943

# %%
correlation_df_continents = df_continents.corr()

# %%
correlation_df_continents
# Out:
#                           ATHLETES      GOLD    SILVER    BRONZE  \
# ATHLETES                  1.000000  0.957238  0.992163  0.984252
# GOLD                      0.957238  1.000000  0.980132  0.990701
# SILVER                    0.992163  0.980132  1.000000  0.992233
# BRONZE                    0.984252  0.990701  0.992233  1.000000
# TOTAL_MEDAL_BY_CONTINENT  0.982848  0.993807  0.995174  0.998633
#
#                           TOTAL_MEDAL_BY_CONTINENT
# ATHLETES                                  0.982848
# GOLD                                      0.993807
# SILVER                                    0.995174
# BRONZE                                    0.998633
# TOTAL_MEDAL_BY_CONTINENT                  1.000000

# %%
 correlation_df_continents = correlation_df_continents.drop(["GOLD","SILVER","BRONZE"], axis = 1)

# %%
 correlation_df_continents
# Out:
#                           ATHLETES  TOTAL_MEDAL_BY_CONTINENT
# ATHLETES                  1.000000                  0.982848
# GOLD                      0.957238                  0.993807
# SILVER                    0.992163                  0.995174
# BRONZE                    0.984252                  0.998633
# TOTAL_MEDAL_BY_CONTINENT  0.982848                  1.000000

# %% [markdown]
# # Conclusion: Because we have OR (0.957238) SILVER (0.992163) BRONZEA (0.984252), it means a strong upward (positive) linear relationship between the number of medals and the number of athletes

# %%
df_continents
# Out:
#                ATHLETES   GOLD  SILVER  BRONZE  TOTAL_MEDAL_BY_CONTINENT
# CONTINENTS
# South America     766.0   10.0    15.0    11.0                      36.0
# Africa            984.0   11.0    12.0    14.0                      37.0
# Oceania           791.0   25.0    13.0    30.0                      68.0
# Asia             2334.0   90.0    78.0   101.0                     269.0
# Europe           4822.0  140.0   162.0   185.0                     487.0
# North America    1544.0   61.0    54.0    60.0                     175.0

# %% [markdown]
# # Create new column consisting of row sums across specific columns.

# %%
df_continents['TOTAL MEDAL BY CONTINENT'] = df_continents.iloc[:,0:4].sum(axis=1)

# %%
df_continents2 =  df_continents.iloc[:,0:4].sum(axis=1)

# %%
df_continents2
# Out:
# CONTINENTS
# South America     802.0
# Africa           1021.0
# Oceania           859.0
# Asia             2603.0
# Europe           5309.0
# North America    1719.0
# dtype: float64

# %%
df_continents['TOTAL MEDAL BY CONTINENT']
# Out:
# CONTINENTS
# South America     802.0
# Africa           1021.0
# Oceania           859.0
# Asia             2603.0
# Europe           5309.0
# North America    1719.0
# Name: TOTAL MEDAL BY CONTINENT, dtype: float64

# %%
df_continents
# Out:
#                ATHLETES   GOLD  SILVER  BRONZE  TOTAL_MEDAL_BY_CONTINENT  \
# CONTINENTS
# South America     766.0   10.0    15.0    11.0                      36.0
# Africa            984.0   11.0    12.0    14.0                      37.0
# Oceania           791.0   25.0    13.0    30.0                      68.0
# Asia             2334.0   90.0    78.0   101.0                     269.0
# Europe           4822.0  140.0   162.0   185.0                     487.0
# North America    1544.0   61.0    54.0    60.0                     175.0
#
#                TOTAL MEDAL BY CONTINENT
# CONTINENTS
# South America                     802.0
# Africa                           1021.0
# Oceania                           859.0
# Asia                             2603.0
# Europe                           5309.0
# North America                    1719.0

# %%
df_continents
# Out:
#                ATHLETES   GOLD  SILVER  BRONZE  TOTAL_MEDAL_BY_CONTINENT  \
# CONTINENTS
# South America     766.0   10.0    15.0    11.0                      36.0
# Africa            984.0   11.0    12.0    14.0                      37.0
# Oceania           791.0   25.0    13.0    30.0                      68.0
# Asia             2334.0   90.0    78.0   101.0                     269.0
# Europe           4822.0  140.0   162.0   185.0                     487.0
# North America    1544.0   61.0    54.0    60.0                     175.0
#
#                TOTAL MEDAL BY CONTINENT
# CONTINENTS
# South America                     802.0
# Africa                           1021.0
# Oceania                           859.0
# Asia                             2603.0
# Europe                           5309.0
# North America                    1719.0

# %% [markdown]
# # Sort DataFrame based on column names or row

# %%
df_continents.sort_values(by='CONTINENTS', inplace=True)

# %%
df_continents
# Out:
#                ATHLETES   GOLD  SILVER  BRONZE  TOTAL_MEDAL_BY_CONTINENT  \
# CONTINENTS
# Africa            984.0   11.0    12.0    14.0                      37.0
# Asia             2334.0   90.0    78.0   101.0                     269.0
# Europe           4822.0  140.0   162.0   185.0                     487.0
# North America    1544.0   61.0    54.0    60.0                     175.0
# Oceania           791.0   25.0    13.0    30.0                      68.0
# South America     766.0   10.0    15.0    11.0                      36.0
#
#                TOTAL MEDAL BY CONTINENT
# CONTINENTS
# Africa                           1021.0
# Asia                             2603.0
# Europe                           5309.0
# North America                    1719.0
# Oceania                           859.0
# South America                     802.0

# %% [markdown]
# # TOTAL MEDAL BY CONTINENT

# %%
df_continents['TOTAL MEDAL BY CONTINENT'].plot(kind = 'bar', figsize=(12,8), color='#86bf91')
plt.title("TOTAL MEDAL BY CONTINENT")

plt.xlabel("CONTINENTS")
plt.xticks(rotation=30, horizontalalignment="center")
plt.ylabel("TOTAL MEDAL")

plt.show()

# %% [markdown]
# # Which continent did better or worse at the Tokyo Olympics? Why?Is there an economic impact on the performance of athletes by continent?

# %% [markdown]
# # To answer this question, I collected information from wikipedia.
# Sources: https://en.wikipedia.org/wiki/List_of_continents_by_GDP_(nominal)#cite_note-IMF01-3

# %%
#Import data from the web to Excel,

#Import  Excel File into Python using Pandas,

#I combined data in Pandas by merging, joining and concating,

#I selected rows from my DataFrames based on column values,

#I have selected columns from my DataFrames by index,

# %%
import pandas as pdGDP
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dfGDP = pdGDP.read_excel('/content/drive/MyDrive/Data_Engineering/Tokyo Olympics 2020(2021)/Olympic Medal Count 2020.xlsx',
                    sheet_name='GDP (nominal) by continents')

# %%
dfGDP
# Out:
#    Rank      Continent  GDP (US$billion)  Share (%)
# 0   NaN          World           93864.0      100.0
# 1   1.0           Asia           36383.0       38.8
# 2   2.0  North America           26298.0       28.0
# 3   3.0         Europe           23614.0       25.2
# 4   4.0  South America            3019.0        3.2
# 5   5.0         Africa            2601.0        2.8
# 6   6.0        Oceania            1894.0        2.0
# 7   NaN    Unaccounted              55.0        0.1

# %%
dfGDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              6 non-null      float64
#  1   Continent         8 non-null      object
#  2   GDP (US$billion)  8 non-null      float64
#  3   Share (%)         8 non-null      float64
# dtypes: float64(3), object(1)
# memory usage: 384.0+ bytes

# %%
 dfGDP
# Out:
#    Rank      Continent  GDP (US$billion)  Share (%)
# 0   NaN          World           93864.0      100.0
# 1   1.0           Asia           36383.0       38.8
# 2   2.0  North America           26298.0       28.0
# 3   3.0         Europe           23614.0       25.2
# 4   4.0  South America            3019.0        3.2
# 5   5.0         Africa            2601.0        2.8
# 6   6.0        Oceania            1894.0        2.0
# 7   NaN    Unaccounted              55.0        0.1

# %%
dfGDP.rename(columns={'Continent': 'CONTINENTS'},
          inplace=True, errors='raise')

# %%
dfGDP
# Out:
#    Rank     CONTINENTS  GDP (US$billion)  Share (%)
# 0   NaN          World           93864.0      100.0
# 1   1.0           Asia           36383.0       38.8
# 2   2.0  North America           26298.0       28.0
# 3   3.0         Europe           23614.0       25.2
# 4   4.0  South America            3019.0        3.2
# 5   5.0         Africa            2601.0        2.8
# 6   6.0        Oceania            1894.0        2.0
# 7   NaN    Unaccounted              55.0        0.1

# %%
dfGDP.set_index('CONTINENTS', inplace=True)

# %%
dfGDP
# Out:
#                Rank  GDP (US$billion)  Share (%)
# CONTINENTS
# World           NaN           93864.0      100.0
# Asia            1.0           36383.0       38.8
# North America   2.0           26298.0       28.0
# Europe          3.0           23614.0       25.2
# South America   4.0            3019.0        3.2
# Africa          5.0            2601.0        2.8
# Oceania         6.0            1894.0        2.0
# Unaccounted     NaN              55.0        0.1

# %%
dfGDP.drop(['Rank','Share (%)'], inplace=True, axis=1)

# %%
dfGDP
# Out:
#                GDP (US$billion)
# CONTINENTS
# World                   93864.0
# Asia                    36383.0
# North America           26298.0
# Europe                  23614.0
# South America            3019.0
# Africa                   2601.0
# Oceania                  1894.0
# Unaccounted                55.0

# %%
# Delete rows with index name
dfGDP2 = dfGDP.drop(['World' , 'Unaccounted'])

# %%
dfGDP2.sort_values(by='CONTINENTS')
# Out:
#                GDP (US$billion)
# CONTINENTS
# Africa                   2601.0
# Asia                    36383.0
# Europe                  23614.0
# North America           26298.0
# Oceania                  1894.0
# South America            3019.0

# %%
dfconticoncate = pd.concat([dfGDP2, df_continents], axis=1, join='inner')

# %%
dfconticoncate
# Out:
#                GDP (US$billion)  ATHLETES   GOLD  SILVER  BRONZE  \
# CONTINENTS
# Asia                    36383.0    2334.0   90.0    78.0   101.0
# North America           26298.0    1544.0   61.0    54.0    60.0
# Europe                  23614.0    4822.0  140.0   162.0   185.0
# South America            3019.0     766.0   10.0    15.0    11.0
# Africa                   2601.0     984.0   11.0    12.0    14.0
# Oceania                  1894.0     791.0   25.0    13.0    30.0
#
#                TOTAL_MEDAL_BY_CONTINENT  TOTAL MEDAL BY CONTINENT
# CONTINENTS
# Asia                              269.0                    2603.0
# North America                     175.0                    1719.0
# Europe                            487.0                    5309.0
# South America                      36.0                     802.0
# Africa                             37.0                    1021.0
# Oceania                            68.0                     859.0

# %%
dfGDP2['GDP (US$billion)'].plot(kind = 'bar', figsize=(12,8), color='red')
plt.title("GDP BY CONTINENT")

plt.xlabel("CONTINENTS")
plt.xticks(rotation=30, horizontalalignment="center")
plt.ylabel("GDP (US$billion)")

plt.show()

# %%
dfGDP
# Out:
#                GDP (US$billion)
# CONTINENTS
# World                   93864.0
# Asia                    36383.0
# North America           26298.0
# Europe                  23614.0
# South America            3019.0
# Africa                   2601.0
# Oceania                  1894.0
# Unaccounted                55.0

# %% [markdown]
# # Find the correlation between the GDP (billions of US dollars) by continent and the total number of medal by continent.

# %%
corr_GDP_Total_medals = dfconticoncate["GDP (US$billion)"].corr(dfconticoncate["TOTAL MEDAL BY CONTINENT"])

# %%
corr_GDP_Total_medals
# Out:
# 0.6101211549068609

# %% [markdown]
# # Conclusion: corr_GDP_Total_medals = 0.61: A moderate positive relationship.

# %% [markdown]
# # Find the correlation between the GDP (billions of US dollars) by continent and the total number of athlete by continent.

# %%
corr_GDP_Total_Athletes = dfconticoncate["GDP (US$billion)"].corr(dfconticoncate["ATHLETES"])

# %%
corr_GDP_Total_Athletes
# Out:
# 0.5972888225383218

# %% [markdown]
# # Conclusion: corr_GDP_Total_Athletes = 0.59: A moderate positive relationship.

# %% [markdown]
# # REPRESENTATION OF GDP (in billions of US dollars) BY CONTINENT, TOTAL ATHLETES BY CONTINENT AND TOTAL MEDALS BY CONTINENT

# %%
dfconticoncate[['GDP (US$billion)','ATHLETES','TOTAL MEDAL BY CONTINENT']].plot(kind = 'bar', figsize=(12,8))
plt.title("REPRESENTATION OF GDP (in billions of US dollars) BY CONTINENT, TOTAL ATHLETES BY CONTINENT AND TOTAL MEDALS BY CONTINENT")

plt.xlabel("CONTINENTS")
plt.xticks(rotation=30, horizontalalignment="center")
plt.ylabel("GDP (US$billion)")

plt.show()

# %% [markdown]
# # Conclusion: No strong impact of the economy on the performance of athletes by continent
